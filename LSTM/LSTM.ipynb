# %%
import pandas as pd
import re
import pickle
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as sq

from collections import defaultdict
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

from keras import layers, optimizers
from keras.models import Sequential, load_model
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, SimpleRNN, Activation, Flatten
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras import backend as K
# Out:
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Prepare Dataset

# %%
conn = sq.connect('C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/database_pl.db', check_same_thread = False)
q_data = 'SELECT * FROM data'
df = pd.read_sql_query(q_data, conn)
df.head(10)
# Out:
#                                                Tweet     Label
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatra bandung temp...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...  negative
# 5  makanan beragam harga makanan di food stall ak...  positive
# 6  pakai kartu kredit baca tidak untung malah rug...  negative
# 7  tempat unik bagus buat foto makanan enak pegaw...  positive
# 8  saya bersama keluarga baru saja menikmati peng...  positive
# 9                                          bersyukur  positive

# %%
df['Label'].value_counts()
# Out:
# Label
# positive    6383
# negative    3412
# neutral     1138
# Name: count, dtype: int64

# %% [markdown]
# # Feature Label Classification

# %%
# memfilter data berdasarkan label
df_positive = df[df['Label'] == 'positive']
df_negative = df[df['Label'] == 'negative']
df_neutral = df[df['Label'] == 'neutral']

# menyeimbangkan label netral dengan label negatif
df_neutral_over = df_neutral.sample(df_negative.shape[0], replace=True)

# menggabungkan semua data
df = pd.concat([df_positive, df_negative, df_neutral_over])

# mengecek kembali
label_counts = df['Label'].value_counts()
print(label_counts)
# Out:
# Label
# positive    6383
# negative    3412
# neutral     3412
# Name: count, dtype: int64

# %%
# Group data tweet
positive_tweet = df.loc[df['Label']=='positive'].Tweet.tolist()
negative_tweet = df.loc[df['Label']=='negative'].Tweet.tolist()
neutral_tweet = df.loc[df['Label']=='neutral'].Tweet.tolist()

# Group df label
positive_label = df.loc[df['Label']=='positive'].Label.tolist()
negative_label = df.loc[df['Label']=='negative'].Label.tolist()
neutral_label = df.loc[df['Label']=='neutral'].Label.tolist()

total_data = positive_tweet + negative_tweet + neutral_tweet
labels = positive_label + negative_label + neutral_label

print("Positive: %s, Negative: %s, Neutral: %s" % (len(positive_tweet), len(neutral_tweet), len(negative_tweet)))
print("Total data: %s" % len(total_data))
print("Total labels: %s" % len(labels))
# Out:
# Positive: 6383, Negative: 3412, Neutral: 3412
# Total data: 13207
# Total labels: 13207

# %% [markdown]
# # Feature Extraction

# %%
max_features = 5000
tokenizer = Tokenizer(num_words=max_features, split=' ', lower=True)
tokenizer.fit_on_texts(total_data)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("tokenizer.pickle has created!")

X = tokenizer.texts_to_sequences(total_data)  

vocab_size = len(tokenizer.word_index)
maxlen = max(len(x) for x in X)

X = pad_sequences(X)
with open('x_pad_sequences.pickle', 'wb') as handle:
    pickle.dump(X, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("x_pad_sequences.pickle has created!")
# Out:
# tokenizer.pickle has created!
# x_pad_sequences.pickle has created!

# %%
Y = pd.get_dummies(labels)
Y = Y.values

with open('y_labels.pickle', 'wb') as handle:
    pickle.dump(Y, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("y_labels.pickle has created!")
# Out:
# y_labels.pickle has created!

# %%
file = open("C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/LSTM/x_pad_sequences.pickle",'rb')
X = pickle.load(file)
file.close()

file = open("C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/LSTM/y_labels.pickle",'rb')
Y = pickle.load(file)
file.close()

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Training, Model Evaluation, Cross Validation

# %%
embed_dim = 200
units = 64

model = Sequential()
model.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
model.add(LSTM(units, dropout=0.8))
model.add(Dense(3,activation='softmax'))
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
print(model.summary())

adam = optimizers.Adam(learning_rate = 0.00005)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[es])
# Out:
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 87, 200)           1000000
#
#  lstm (LSTM)                 (None, 64)                67840
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 1068035 (4.07 MB)
# Trainable params: 1068035 (4.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 331/331 [==============================] - 29s 72ms/step - loss: 0.9771 - accuracy: 0.5878 - val_loss: 0.7987 - val_accuracy: 0.6506
# Epoch 2/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.7553 - accuracy: 0.6653 - val_loss: 0.7120 - val_accuracy: 0.6677
# Epoch 3/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.6873 - accuracy: 0.6852 - val_loss: 0.6529 - val_accuracy: 0.6904
# Epoch 4/50
# 331/331 [==============================] - 23s 70ms/step - loss: 0.6382 - accuracy: 0.7031 - val_loss: 0.6055 - val_accuracy: 0.7082
# Epoch 5/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.5923 - accuracy: 0.7391 - val_loss: 0.5584 - val_accuracy: 0.7801
# Epoch 6/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.5438 - accuracy: 0.7824 - val_loss: 0.5058 - val_accuracy: 0.8130
# Epoch 7/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.4911 - accuracy: 0.8198 - val_loss: 0.4463 - val_accuracy: 0.8475
# Epoch 8/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.4446 - accuracy: 0.8407 - val_loss: 0.4075 - val_accuracy: 0.8588
# Epoch 9/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.4001 - accuracy: 0.8550 - val_loss: 0.3771 - val_accuracy: 0.8660
# Epoch 10/50
# 331/331 [==============================] - 23s 70ms/step - loss: 0.3743 - accuracy: 0.8628 - val_loss: 0.3618 - val_accuracy: 0.8728
# Epoch 11/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.3514 - accuracy: 0.8724 - val_loss: 0.3420 - val_accuracy: 0.8804
# Epoch 12/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.3314 - accuracy: 0.8803 - val_loss: 0.3237 - val_accuracy: 0.8827
# Epoch 13/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.3170 - accuracy: 0.8855 - val_loss: 0.3148 - val_accuracy: 0.8861
# Epoch 14/50
# 331/331 [==============================] - 23s 68ms/step - loss: 0.2997 - accuracy: 0.8931 - val_loss: 0.3060 - val_accuracy: 0.8914
# Epoch 15/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.2840 - accuracy: 0.8998 - val_loss: 0.2968 - val_accuracy: 0.8910
# Epoch 16/50
# 331/331 [==============================] - 23s 68ms/step - loss: 0.2754 - accuracy: 0.9003 - val_loss: 0.2905 - val_accuracy: 0.8925
# Epoch 17/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.2668 - accuracy: 0.9055 - val_loss: 0.2869 - val_accuracy: 0.8967
# Epoch 18/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.2582 - accuracy: 0.9059 - val_loss: 0.2783 - val_accuracy: 0.8959
# Epoch 19/50
# 331/331 [==============================] - 23s 69ms/step - loss: 0.2450 - accuracy: 0.9105 - val_loss: 0.2826 - val_accuracy: 0.9008
# Epoch 19: early stopping

# %%
predictions = model.predict(X_test)
y_pred = predictions
matrix_test = metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("Testing selesai")
print(matrix_test)
# Out:
# 83/83 [==============================] - 3s 23ms/step
# Testing selesai
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       709
#            1       0.93      0.94      0.94       662
#            2       0.93      0.91      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642

# %%
kf = KFold(n_splits=5, random_state=42, shuffle=True)

accuracies = []

y = Y

embed_dim = 200
units = 64

for iteration, data in enumerate(kf.split(X), start=1):

    data_train   = X[data[0]]
    target_train = y[data[0]]

    data_test    = X[data[1]]
    target_test  = y[data[1]]

    model = Sequential()
    model.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
    model.add(LSTM(units, dropout=0.8))
    model.add(Dense(3,activation='softmax'))
    model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

    adam = optimizers.Adam(learning_rate = 0.00005)
    model.compile(loss = 'categorical_crossentropy', optimizer=adam, metrics = ['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[es])

    predictions = model.predict(X_test)
    y_pred = predictions
    
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    print("Training ke-", iteration)
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

average_accuracy = np.mean(accuracies)

print()
print()
print()
print("Rata-rata Accuracy: ", average_accuracy)
# Out:
# Epoch 1/50
# 331/331 [==============================] - 31s 78ms/step - loss: 0.9986 - accuracy: 0.5638 - val_loss: 0.8108 - val_accuracy: 0.6522
# Epoch 2/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.7621 - accuracy: 0.6654 - val_loss: 0.7201 - val_accuracy: 0.6635
# Epoch 3/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.6960 - accuracy: 0.6793 - val_loss: 0.6691 - val_accuracy: 0.6787
# Epoch 4/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.6535 - accuracy: 0.6922 - val_loss: 0.6252 - val_accuracy: 0.6961
# Epoch 5/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.6067 - accuracy: 0.7209 - val_loss: 0.5744 - val_accuracy: 0.7275
# Epoch 6/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.5550 - accuracy: 0.7730 - val_loss: 0.5149 - val_accuracy: 0.8013
# Epoch 7/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.4989 - accuracy: 0.8180 - val_loss: 0.4616 - val_accuracy: 0.8505
# Epoch 8/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.4525 - accuracy: 0.8380 - val_loss: 0.4258 - val_accuracy: 0.8482
# Epoch 9/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.4124 - accuracy: 0.8547 - val_loss: 0.3879 - val_accuracy: 0.8634
# Epoch 10/50
# 331/331 [==============================] - 24s 74ms/step - loss: 0.3846 - accuracy: 0.8599 - val_loss: 0.3673 - val_accuracy: 0.8717
# Epoch 11/50
# 331/331 [==============================] - 24s 73ms/step - loss: 0.3567 - accuracy: 0.8710 - val_loss: 0.3493 - val_accuracy: 0.8743
# Epoch 12/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.3385 - accuracy: 0.8783 - val_loss: 0.3355 - val_accuracy: 0.8819
# Epoch 13/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.3202 - accuracy: 0.8838 - val_loss: 0.3207 - val_accuracy: 0.8830
# Epoch 14/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.3019 - accuracy: 0.8956 - val_loss: 0.3146 - val_accuracy: 0.8887
# Epoch 15/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.2913 - accuracy: 0.8971 - val_loss: 0.3018 - val_accuracy: 0.8940
# Epoch 16/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.2805 - accuracy: 0.9022 - val_loss: 0.2925 - val_accuracy: 0.8944
# Epoch 17/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.2654 - accuracy: 0.9071 - val_loss: 0.2851 - val_accuracy: 0.8955
# Epoch 18/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.2562 - accuracy: 0.9085 - val_loss: 0.2833 - val_accuracy: 0.8974
# Epoch 19/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.2455 - accuracy: 0.9133 - val_loss: 0.2740 - val_accuracy: 0.8997
# Epoch 20/50
# 331/331 [==============================] - 25s 74ms/step - loss: 0.2348 - accuracy: 0.9171 - val_loss: 0.2799 - val_accuracy: 0.8993
# Epoch 20: early stopping
# 83/83 [==============================] - 3s 22ms/step
# Training ke- 1
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       709
#            1       0.91      0.95      0.93       662
#            2       0.91      0.92      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.89      0.89      0.89      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 29s 77ms/step - loss: 0.9796 - accuracy: 0.5750 - val_loss: 0.7981 - val_accuracy: 0.6469
# Epoch 2/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.7560 - accuracy: 0.6655 - val_loss: 0.7184 - val_accuracy: 0.6658
# Epoch 3/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.6937 - accuracy: 0.6800 - val_loss: 0.6617 - val_accuracy: 0.6862
# Epoch 4/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.6399 - accuracy: 0.7035 - val_loss: 0.6189 - val_accuracy: 0.7017
# Epoch 5/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.5917 - accuracy: 0.7341 - val_loss: 0.5588 - val_accuracy: 0.7581
# Epoch 6/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.5434 - accuracy: 0.7824 - val_loss: 0.5115 - val_accuracy: 0.8073
# Epoch 7/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.4925 - accuracy: 0.8139 - val_loss: 0.4609 - val_accuracy: 0.8327
# Epoch 8/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.4517 - accuracy: 0.8296 - val_loss: 0.4208 - val_accuracy: 0.8600
# Epoch 9/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.4129 - accuracy: 0.8486 - val_loss: 0.3897 - val_accuracy: 0.8618
# Epoch 10/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.3822 - accuracy: 0.8558 - val_loss: 0.3623 - val_accuracy: 0.8751
# Epoch 11/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.3567 - accuracy: 0.8649 - val_loss: 0.3470 - val_accuracy: 0.8709
# Epoch 12/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.3348 - accuracy: 0.8752 - val_loss: 0.3276 - val_accuracy: 0.8808
# Epoch 13/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.3153 - accuracy: 0.8826 - val_loss: 0.3151 - val_accuracy: 0.8842
# Epoch 14/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.2987 - accuracy: 0.8888 - val_loss: 0.3097 - val_accuracy: 0.8846
# Epoch 15/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.2920 - accuracy: 0.8931 - val_loss: 0.3022 - val_accuracy: 0.8891
# Epoch 16/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2768 - accuracy: 0.8970 - val_loss: 0.2926 - val_accuracy: 0.8925
# Epoch 17/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.2687 - accuracy: 0.9023 - val_loss: 0.2831 - val_accuracy: 0.8989
# Epoch 18/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.2563 - accuracy: 0.9086 - val_loss: 0.2829 - val_accuracy: 0.8986
# Epoch 19/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.2483 - accuracy: 0.9092 - val_loss: 0.2789 - val_accuracy: 0.8993
# Epoch 20/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.2367 - accuracy: 0.9142 - val_loss: 0.2716 - val_accuracy: 0.9008
# Epoch 21/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.2261 - accuracy: 0.9206 - val_loss: 0.2651 - val_accuracy: 0.9042
# Epoch 22/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.2236 - accuracy: 0.9214 - val_loss: 0.2608 - val_accuracy: 0.9050
# Epoch 23/50
# 331/331 [==============================] - 24s 72ms/step - loss: 0.2169 - accuracy: 0.9238 - val_loss: 0.2569 - val_accuracy: 0.9035
# Epoch 24/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.2060 - accuracy: 0.9283 - val_loss: 0.2593 - val_accuracy: 0.9035
# Epoch 24: early stopping
# 83/83 [==============================] - 2s 21ms/step
# Training ke- 2
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       709
#            1       0.92      0.96      0.94       662
#            2       0.93      0.92      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 27s 71ms/step - loss: 0.9813 - accuracy: 0.5962 - val_loss: 0.7935 - val_accuracy: 0.6525
# Epoch 2/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.7483 - accuracy: 0.6687 - val_loss: 0.7090 - val_accuracy: 0.6658
# Epoch 3/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.6883 - accuracy: 0.6859 - val_loss: 0.6605 - val_accuracy: 0.6877
# Epoch 4/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.6387 - accuracy: 0.7090 - val_loss: 0.6120 - val_accuracy: 0.7063
# Epoch 5/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.5866 - accuracy: 0.7503 - val_loss: 0.5464 - val_accuracy: 0.7827
# Epoch 6/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.5251 - accuracy: 0.7996 - val_loss: 0.4752 - val_accuracy: 0.8350
# Epoch 7/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.4681 - accuracy: 0.8279 - val_loss: 0.4247 - val_accuracy: 0.8528
# Epoch 8/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.4236 - accuracy: 0.8428 - val_loss: 0.3935 - val_accuracy: 0.8683
# Epoch 9/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.3956 - accuracy: 0.8568 - val_loss: 0.3729 - val_accuracy: 0.8653
# Epoch 10/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.3683 - accuracy: 0.8664 - val_loss: 0.3590 - val_accuracy: 0.8694
# Epoch 11/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.3504 - accuracy: 0.8726 - val_loss: 0.3361 - val_accuracy: 0.8808
# Epoch 12/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.3299 - accuracy: 0.8804 - val_loss: 0.3252 - val_accuracy: 0.8842
# Epoch 13/50
# 331/331 [==============================] - 24s 71ms/step - loss: 0.3137 - accuracy: 0.8874 - val_loss: 0.3128 - val_accuracy: 0.8895
# Epoch 14/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2972 - accuracy: 0.8916 - val_loss: 0.3044 - val_accuracy: 0.8876
# Epoch 15/50
# 331/331 [==============================] - 23s 70ms/step - loss: 0.2852 - accuracy: 0.8954 - val_loss: 0.2978 - val_accuracy: 0.8933
# Epoch 16/50
# 331/331 [==============================] - 23s 70ms/step - loss: 0.2751 - accuracy: 0.9002 - val_loss: 0.2907 - val_accuracy: 0.8940
# Epoch 17/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2635 - accuracy: 0.9070 - val_loss: 0.2848 - val_accuracy: 0.8974
# Epoch 18/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2551 - accuracy: 0.9107 - val_loss: 0.2772 - val_accuracy: 0.8989
# Epoch 19/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2478 - accuracy: 0.9128 - val_loss: 0.2719 - val_accuracy: 0.8997
# Epoch 20/50
# 331/331 [==============================] - 23s 71ms/step - loss: 0.2364 - accuracy: 0.9185 - val_loss: 0.2731 - val_accuracy: 0.9020
# Epoch 20: early stopping
# 83/83 [==============================] - 2s 21ms/step
# Training ke- 3
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       709
#            1       0.92      0.96      0.94       662
#            2       0.93      0.91      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 34s 82ms/step - loss: 0.9862 - accuracy: 0.5752 - val_loss: 0.8000 - val_accuracy: 0.6518
# Epoch 2/50
# 331/331 [==============================] - 26s 79ms/step - loss: 0.7490 - accuracy: 0.6620 - val_loss: 0.7051 - val_accuracy: 0.6669
# Epoch 3/50
# 331/331 [==============================] - 26s 79ms/step - loss: 0.6777 - accuracy: 0.6851 - val_loss: 0.6472 - val_accuracy: 0.6802
# Epoch 4/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.6193 - accuracy: 0.7128 - val_loss: 0.5875 - val_accuracy: 0.7173
# Epoch 5/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.5735 - accuracy: 0.7594 - val_loss: 0.5405 - val_accuracy: 0.7767
# Epoch 6/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.5233 - accuracy: 0.7956 - val_loss: 0.4879 - val_accuracy: 0.8478
# Epoch 7/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.4740 - accuracy: 0.8291 - val_loss: 0.4415 - val_accuracy: 0.8539
# Epoch 8/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.4341 - accuracy: 0.8416 - val_loss: 0.4030 - val_accuracy: 0.8671
# Epoch 9/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.3952 - accuracy: 0.8554 - val_loss: 0.3782 - val_accuracy: 0.8702
# Epoch 10/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.3677 - accuracy: 0.8679 - val_loss: 0.3567 - val_accuracy: 0.8777
# Epoch 11/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.3482 - accuracy: 0.8740 - val_loss: 0.3378 - val_accuracy: 0.8800
# Epoch 12/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.3294 - accuracy: 0.8810 - val_loss: 0.3251 - val_accuracy: 0.8838
# Epoch 13/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.3156 - accuracy: 0.8869 - val_loss: 0.3168 - val_accuracy: 0.8849
# Epoch 14/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2971 - accuracy: 0.8923 - val_loss: 0.3073 - val_accuracy: 0.8906
# Epoch 15/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2839 - accuracy: 0.8970 - val_loss: 0.2941 - val_accuracy: 0.8902
# Epoch 16/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2727 - accuracy: 0.9051 - val_loss: 0.2924 - val_accuracy: 0.8955
# Epoch 17/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2596 - accuracy: 0.9051 - val_loss: 0.2861 - val_accuracy: 0.8955
# Epoch 18/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2462 - accuracy: 0.9127 - val_loss: 0.2786 - val_accuracy: 0.8993
# Epoch 19/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2425 - accuracy: 0.9162 - val_loss: 0.2738 - val_accuracy: 0.8982
# Epoch 20/50
# 331/331 [==============================] - 26s 78ms/step - loss: 0.2341 - accuracy: 0.9151 - val_loss: 0.2684 - val_accuracy: 0.9023
# Epoch 21/50
# 331/331 [==============================] - 26s 77ms/step - loss: 0.2257 - accuracy: 0.9206 - val_loss: 0.2711 - val_accuracy: 0.9050
# Epoch 21: early stopping
# 83/83 [==============================] - 3s 23ms/step
# Training ke- 4
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       709
#            1       0.94      0.95      0.95       662
#            2       0.92      0.91      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.91      0.90      0.91      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 30s 78ms/step - loss: 1.0043 - accuracy: 0.5621 - val_loss: 0.8112 - val_accuracy: 0.6488
# Epoch 2/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.7660 - accuracy: 0.6595 - val_loss: 0.7250 - val_accuracy: 0.6635
# Epoch 3/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.6981 - accuracy: 0.6818 - val_loss: 0.6698 - val_accuracy: 0.6809
# Epoch 4/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.6429 - accuracy: 0.7047 - val_loss: 0.6073 - val_accuracy: 0.7033
# Epoch 5/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.5847 - accuracy: 0.7483 - val_loss: 0.5400 - val_accuracy: 0.8039
# Epoch 6/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.5173 - accuracy: 0.8121 - val_loss: 0.4731 - val_accuracy: 0.8210
# Epoch 7/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.4609 - accuracy: 0.8334 - val_loss: 0.4242 - val_accuracy: 0.8460
# Epoch 8/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.4173 - accuracy: 0.8468 - val_loss: 0.3908 - val_accuracy: 0.8668
# Epoch 9/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.3857 - accuracy: 0.8588 - val_loss: 0.3641 - val_accuracy: 0.8713
# Epoch 10/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.3633 - accuracy: 0.8695 - val_loss: 0.3460 - val_accuracy: 0.8789
# Epoch 11/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.3415 - accuracy: 0.8768 - val_loss: 0.3325 - val_accuracy: 0.8796
# Epoch 12/50
# 331/331 [==============================] - 25s 77ms/step - loss: 0.3261 - accuracy: 0.8838 - val_loss: 0.3213 - val_accuracy: 0.8849
# Epoch 13/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.3093 - accuracy: 0.8892 - val_loss: 0.3119 - val_accuracy: 0.8868
# Epoch 14/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.2942 - accuracy: 0.8928 - val_loss: 0.3063 - val_accuracy: 0.8925
# Epoch 15/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.2831 - accuracy: 0.9001 - val_loss: 0.2942 - val_accuracy: 0.8940
# Epoch 16/50
# 331/331 [==============================] - 25s 75ms/step - loss: 0.2707 - accuracy: 0.9076 - val_loss: 0.2890 - val_accuracy: 0.8948
# Epoch 17/50
# 331/331 [==============================] - 25s 77ms/step - loss: 0.2585 - accuracy: 0.9100 - val_loss: 0.2871 - val_accuracy: 0.8989
# Epoch 18/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.2489 - accuracy: 0.9137 - val_loss: 0.2765 - val_accuracy: 0.9001
# Epoch 19/50
# 331/331 [==============================] - 25s 77ms/step - loss: 0.2421 - accuracy: 0.9158 - val_loss: 0.2690 - val_accuracy: 0.9008
# Epoch 20/50
# 331/331 [==============================] - 25s 76ms/step - loss: 0.2345 - accuracy: 0.9161 - val_loss: 0.2700 - val_accuracy: 0.9054
# Epoch 20: early stopping
# 83/83 [==============================] - 3s 22ms/step
# Training ke- 5
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       709
#            1       0.94      0.95      0.95       662
#            2       0.93      0.91      0.92      1271
#
#     accuracy                           0.91      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.91      0.91      0.91      2642
#
# ======================================================
#
#
#
# Rata-rata Accuracy:  0.9030280090840274

# %% [markdown]
# # Visualization & Evalution

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b-', label='Training acc')
    plt.plot(x, val_acc, 'r-', label='Validation acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b-', label='Training loss')
    plt.plot(x, val_loss, 'r-', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

plot_history(history)
plt.show()

# %%
# Save the model

model.save('model.h5')
print("Model has created!")
# Out:
# C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model has created!

# %%
input_text = """Rasa bersyukur, cukup."""

def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

sentiment = ['negative', 'neutral', 'positive']

text = [cleansing(input_text)]
predicted = tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/LSTM/model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: %s" % text[0])
print("Sentiment: %s" % sentiment[polarity])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Text: rasa bersyukur  cukup
# Sentiment: positive

# %%
input_text = """Makanannya busuk"""

def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

sentiment = ['negative', 'neutral', 'positive']

text = [cleansing(input_text)]
predicted = tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/LSTM/model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: %s" % text[0])
print("Sentiment: %s" % sentiment[polarity])
